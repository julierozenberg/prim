# %%
import sqlalchemy
import pandas as pd

# %%
#engine = create_engine('mssql+pyodbc://scott:tiger@mydsn')
#dialect+driver://username:password@host:port/database

# %%
#engine = sqlalchemy.create_engine('mssql+pyodbc://datareader:DataReader9!@wbmserccar101/POVANA13')
engine = sqlalchemy.create_engine('mssql+pyodbc://wbmserccar101/POVANA14')

# %% [markdown]
# ## Imports data for Julie's model and exports to csv

# %%
hh_characteristics=pd.read_sql_query("SELECT * FROM combined.hhlddata", engine)
persdata=pd.read_sql_query("SELECT * FROM combined.persdata", engine)
consumption=pd.read_sql_query("SELECT * FROM Combined.PerCapitaExpenditures", engine)

# %%
import time
day=time.strftime("%Y_%m_%d")
hh_characteristics.to_csv("hh_characteristics_vnm_{}.csv".format(day),index=False)
persdata.to_csv("persdata_vnm_{}.csv".format(day),index=False)
consumption.to_csv("percap_consumption_vnm_{}.csv".format(day),index=False)

# %% [markdown]
# ##### tentative to email the files automatically but it looks like I need admin permission

# %%
tosend=["hh_characteristics_vnm_{}.csv".format(day),"persdata_vnm_{}.csv".format(day),
        "consumption_vnm_{}.csv".format(day)]

import smtplib
from os.path import basename
from email.mime.application import MIMEApplication
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.utils import COMMASPACE, formatdate


def send_mail(send_from, send_to, subject, text, files=None,
              server="127.0.0.1"):
    assert isinstance(send_to, list)

    msg = MIMEMultipart(
        From=send_from,
        To=COMMASPACE.join(send_to),
        Date=formatdate(localtime=True),
        Subject=subject
    )
    msg.attach(MIMEText(text))

    for f in files or []:
        with open(f, "rb") as fil:
            msg.attach(MIMEApplication(
                fil.read(),
                Content_Disposition='attachment; filename="%s"' % basename(f)
            ))

    smtp = smtplib.SMTP(server)
    smtp.sendmail(send_from, send_to, msg.as_string())
    smtp.close()

# %%
send_mail("julie.rozenberg@gmail.com", ["julie.rozenberg@gmail.com"], 'csv files {}'.format(day),
          "", files=tosend)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-de7dd21be98a> in <module>()
#       1 send_mail("julie.rozenberg@gmail.com", ["julie.rozenberg@gmail.com"], 'csv files {}'.format(day),
# ----> 2           "", files=tosend)
#
# <ipython-input-23-d907a9969d8c> in send_mail(send_from, send_to, subject, text, files, server)
#      26             ))
#      27
# ---> 28     smtp = smtplib.SMTP(server)
#      29     smtp.sendmail(send_from, send_to, msg.as_string())
#      30     smtp.close()
#
# C:\Users\wb451855\AppData\Local\Continuum\Anaconda3\lib\smtplib.py in __init__(self, host, port, local_hostname, timeout, source_address)
#     240
#     241         if host:
# --> 242             (code, msg) = self.connect(host, port)
#     243             if code != 220:
#     244                 raise SMTPConnectError(code, msg)
#
# ...

# %% [markdown]
# ## Adrien's things

# %%
#pd.read_sql_table('data', engine)
emissionsbyhousehold = pd.read_sql_table("emissionsbyhousehold",engine,schema="combined")
PerCapitaExpenditures= pd.read_sql_table("PerCapitaExpenditures",engine,schema="combined")
HHLDDATA= pd.read_sql_table("HHLDDATA",engine,schema="combined")
tradedatagtp= pd.read_sql_table("tradedatagtp",engine,schema="combined")
PERSDATA= pd.read_sql_table("PERSDATA",engine,schema="combined")
DecileComposite= pd.read_sql_table("DecileComposite",engine,schema="combined")

# %%
emissionsbyhousehold .to_csv("emissionsbyhousehold.csv")
PerCapitaExpenditures.to_csv("PerCapitaExpenditures.csv")
HHLDDATA             .to_csv("HHLDDATA.csv"             )
tradedatagtp         .to_csv("tradedatagtp.csv"         )
PERSDATA             .to_csv("PERSDATA.csv"             )
DecileComposite      .to_csv("DecileComposite.csv"      )

# %%
hop=pd.read_sql_query("SELECT * FROM  where country='ALB'", engine)

# %%
a=pd.read_sql_query("SELECT * FROM information_schema.tables where table_schema='combined'", engine)
a
# Out:
#   TABLE_CATALOG TABLE_SCHEMA             TABLE_NAME  TABLE_TYPE
# 0      POVANA14     combined           tradedatagtp  BASE TABLE
# 1      POVANA14     combined   emissionsbyhousehold  BASE TABLE
# 2      POVANA14     combined  PerCapitaExpenditures  BASE TABLE
# 3      POVANA14     combined       HouseholdsRanked  BASE TABLE
# 4      POVANA14     combined               PERSDATA  BASE TABLE
# 5      POVANA14     combined               HHLDDATA  BASE TABLE
# 6      POVANA14     combined        DecileComposite  BASE TABLE
# 7      POVANA14     combined          tradedatamcpc  BASE TABLE

# %%
pd.read_sql_query("SELECT HID, SUM(CATINCOME) AS TOTINCOME FROM idatai where country='ALB' AND Ag='hh' and catincome<0 GROUP BY HID", engine)
# Out:
#        HID     TOTINCOME
# 0     1589 -3.707119e+06
# 1     2917 -4.206942e+06
# 2       23 -3.917731e+06
# 3     1566 -1.525419e+06
# 4     2894 -2.808596e+06
# 5       46 -6.438269e+06
# 6      215 -2.745438e+06
# 7     1374 -8.902370e+06
# 8     1543 -4.697962e+06
# 9       69 -2.189150e+06
# 10     192 -2.740877e+06
# 11    1397 -4.254869e+06
# 12    1520 -7.992200e+06
# 13    1420 -1.694438e+06
# 14    2748 -3.141246e+06
# 15    3086 -6.359792e+06
# 16    1443 -4.531500e+06
# 17    2771 -1.555757e+07
# 18    1712 -2.918762e+06
# 19    2794 -7.210331e+06
# 20    3040 -6.414462e+06
# 21    1735 -2.675908e+06
# 22    2817 -1.231462e+08
# 23    2940 -3.579019e+06
# 24    3063 -3.206846e+06
# 25    1251 -6.491100e+06
# 26     361 -1.083731e+06
# 27    1689 -5.680750e+06
# 28    3232 -6.526823e+06
# 29    1297 -1.877931e+06
# ...    ...           ...
# 3634  2407 -1.557608e+07
# 3635   180 -4.148754e+06
# 3636  3426 -8.799573e+06
# 3637   721 -3.816561e+06
# 3638  2642 -6.439408e+06
# ...

# %%
pd.read_sql_query("SELECT top 100 * FROM idatac where country='ALB'", engine)
# Out:
#    COUNTRY  YEAR  HID  HSIZE   EXPENDITURE  PC_EXPENDITURE     HWEIGHT  \
# 0      ALB  2005    1      7   4722873.500    1475898.0000  269.224518
# 1      ALB  2005    2      3   5341900.000    2811526.2500  269.224518
# 2      ALB  2005    3      3   4210642.500    2216127.5000  269.224518
# 3      ALB  2005    4      3   3115111.500    1639532.3750  269.224518
# 4      ALB  2005    5      7   3902066.250    1219395.7500  269.224518
# 5      ALB  2005    6      7   3555030.750    1110947.1250  269.224518
# 6      ALB  2005    7      5   4216685.500    1621802.1250  269.224518
# 7      ALB  2005    8      8   2308146.250     659470.3125  269.224518
# 8      ALB  2005    9      3   4244577.000    2233987.7500  347.809540
# 9      ALB  2005   10      4   3178469.250    1381943.1250  347.809540
# 10     ALB  2005   11      7   3667165.250    1145989.1250  347.809540
# 11     ALB  2005   12      4   3809319.250    1656225.7500  347.809540
# ...

# %%
pd.read_sql_query("SELECT top 100 * FROM idatag where country='ALB' order by 1,2,3,4", engine)
# Out:
#    COUNTRY  YEAR  HID          TP          TPP
# 0      ALB  2005    1        None  SCHOOLYEARS
# 1      ALB  2005    1  1 ALBANIAN       MGROUP
# 2      ALB  2005    1         ALL       REGION
# 3      ALB  2005    1       MALEH          SEX
# 4      ALB  2005    1  NONFARMERG        AGRIC
# 5      ALB  2005    1   NONYOUTHH          AGE
# 6      ALB  2005    1       RURAL         AREA
# 7      ALB  2005    1       TOTAL        TOTAL
# 8      ALB  2005    2        None  SCHOOLYEARS
# 9      ALB  2005    2  1 ALBANIAN       MGROUP
# 10     ALB  2005    2         ALL       REGION
# 11     ALB  2005    2     FARMERG        AGRIC
# 12     ALB  2005    2       MALEH          SEX
# 13     ALB  2005    2   NONYOUTHH          AGE
# 14     ALB  2005    2       RURAL         AREA
# 15     ALB  2005    2       TOTAL        TOTAL
# 16     ALB  2005    3        None  SCHOOLYEARS
# 17     ALB  2005    3  1 ALBANIAN       MGROUP
# 18     ALB  2005    3         ALL       REGION
# ...

# %%
pd.read_sql_query("""select
	a.*
	, b.hweight
	, b.hsize
	, c.*
from
	(
	select 
		COUNTRY, YEAR, HID, -SUM(CATINCOME) as hhincome
	from
		idatai
	where
		catincome<0 and ag='hh'
	group by
		country, year, hid
	) as a
	inner join
	idatac as b
on
	a.country=b.country and a.year= b.year and a.hid=b.hid
	inner join
	(
	select
		*
	from
		idatag as a
		pivot
		(max(tp) for tpp in (age, sex)) as pvt
	) as c
on
	a.country=c.country and c.year= b.year and c.hid=a.hid 
""", engine)
# Out:
#        COUNTRY  YEAR     HID         hhincome      hweight  hsize COUNTRY  \
# 0          IND  2005  392158     31101.000000  4490.750000      4     IND
# 1          MDA  2009    1720     45288.240234   205.139206      4     MDA
# 2          MWI  2004   10875     46955.045410   207.600006      5     MWI
# 3          PAK  2005    6454    360928.000000  2069.782959      5     PAK
# 4          SLE  2011    4405   3362200.000000   125.844498      1     SLE
# 5          GTM  2006     932     37945.000000   580.000000      5     GTM
# 6          CIV  2002   10182    459400.000000    52.718456     11     CIV
# 7          IND  2005  189488     20225.000034  8207.360352      5     IND
# 8          PER  2007   10391      4734.449921   184.449997      3     PER
# 9          UGA  2005    1074    844600.000000   688.309998      7     UGA
# 10         ZMB  2010   19023  11341024.000000   154.377594      5     ZMB
# 11         IND  2005   80377      7719.000000  3893.090088      1     IND
# ...
